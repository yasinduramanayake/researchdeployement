# %%
import pandas as pd
from pycaret.classification import *

# %%
df = pd.read_csv('new_data.csv')
df
# Out:
#    Temperature  Humidity   Target
# 0       35.00C      0.91        1
# 1       30.00C      0.91        1
# 2       26.00C      0.91        1
# 3       27.00C      0.91        1
# 4       28.00C      0.91        1
# 5       29.00C      0.91        1
# 6       31.00C      0.91        1
# 7       32.00C      0.91        1
# 8       33.00C      0.91        1
# 9       34.00C      0.91        1
# 10      26.00C      0.92        1
# 11      27.00C      0.92        1
# 12      28.00C      0.92        1
# 13      29.00C      0.92        1
# 14      30.00C      0.92        1
# 15      31.00C      0.92        1
# 16      32.00C      0.92        1
# 17      33.00C      0.92        1
# 18      34.00C      0.92        1
# 19      35.00C      0.92        1
# 20      26.00C      0.93        1
# 21      27.00C      0.93        1
# 22      28.00C      0.93        1
# 23      29.00C      0.93        1
# 24      30.00C      0.93        1
# 25      31.00C      0.93        1
# ...

# %%
cat_features = ['Temperature', 'Humidity']
experiment = setup(df, target='Target', categorical_features=cat_features)
# Out:
# <style type="text/css">
# #T_2cefd_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2cefd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2cefd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2cefd_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_2cefd_row0_col1" class="data row0 col1" >2365</td>
#     </tr>
#     <tr>
#       <th id="T_2cefd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2cefd_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2cefd_row1_col1" class="data row1 col1" >Target</td>
#     </tr>
#     <tr>
#       <th id="T_2cefd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2cefd_row2_col0" class="data row2 col0" >Target Type</td>
# ...

# %%
top3 = compare_models(n_select = 3)
# Out:
# <style type="text/css">
# #T_b1cb8_ th {
#   text-align: left;
# }
# ...

# %%
save_model(top3[0], model_name='Naive_Bayes')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=['Temperature',
#                                                              'Humidity'],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='Target',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_nume...
#                  ('binn', 'passthrough'), ('rem_outliers', 'passthrough'),
#                  ('cluster_all', 'passthrough'),
# ...
